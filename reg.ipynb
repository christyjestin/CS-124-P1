# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [128, 256, 512, 1024, 2048, 4096, 8192]
y = [0.15450, 0.105021, 0.085148, 0.063156, 0.040723, 0.030502, 0.026732]

# %%
def guess(x):
    return (1/np.log(x) - 0.09) * 1.2

# %%
plt.plot(x,y, label='Original')
plt.plot(x, [guess(i) for i in x])
plt.legend()

# %%
import numpy as np
x_coords = np.array(x)
y_coords = np.array(y)
z = np.polyfit(x, y, 3)
